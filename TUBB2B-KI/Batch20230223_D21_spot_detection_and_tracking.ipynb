# %% [markdown]
# ## Goal
#
# I think it would make sense to move everything to Jupyter notebooks, including the spot detection and tracking to be consistent and organized. For now this notebook should be able to:
#    - load images
#    - perform ROI selection (whether manual or automatic we will have to see)
#    - detect spots (probably with Hmax)
#    - track spots based on denoised images
#    - extract intensities based on raw images
#    - output intensities, track-id, coordinates, etc. similar to TrackMate output
#    - visualize results after every step for quality control

# %%
# Path to images

B2_D21_merged_path = "/Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/Batch20230223/D21/Denoised"
