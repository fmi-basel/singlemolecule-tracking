# %%
import glob
import os
import shutil

import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
# Import images

img_merged_dir = ''
img_merged_path = os.path.join(img_merged_dir,'*.tif')
img_merged_files = np.sort(glob.glob(img_merged_path))

mask_dir = ''
mask_path = os.path.join(mask_dir,'*.tif')
mask_files = np.sort(glob.glob(mask_path))

actin_dir = ''
actin_path = os.path.join(actin_dir,'*.tif')
actin_files = np.sort(glob.glob(actin_path))

tubulin_dir = ''
tubulin_path = os.path.join(tubulin_dir,'*.tif')
tubulin_files = np.sort(glob.glob(tubulin_path))

print(len(img_merged_files))
print(len(mask_files))
print(len(actin_files))
print(len(tubulin_files))
# Out:
# 6
# 6

# %%
# Rename masks

# Function to extract the integer before the first underscore
def extract_integer(file_name):
    return int(file_name.split('_')[0])

# Iterate over both file lists
for img_file, mask_file in zip(img_merged_files, mask_files):
    # Extract the integers from the file names
    img_int = extract_integer(os.path.basename(img_file))
    mask_int = extract_integer(os.path.basename(mask_file))
    
    # Ensure the integers match
    if img_int == mask_int:
        # Extract the base name from the img_merged_file without the extension
        base_name = os.path.splitext(os.path.basename(img_file))[0]
        # Create the new name for the mask file
        new_name = f"{base_name}_ROIs.tif"
        # Construct the full path for the new name
        new_path = os.path.join(os.path.dirname(mask_file), new_name)
        
        # Rename the mask file
        shutil.move(mask_file, new_path)
        print(f"Renamed: {mask_file} -> {new_path}")
    else:
        # Log a mismatch error
        print(f"Mismatch found: {img_file} and {mask_file}. Skipping rename.")
# Out:
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/2_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_2_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/2_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/3_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/3_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/4_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/4_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/5_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/5_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/6_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/6_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/7_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_ROIs.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/ROIs/Cytoplasm/7_100tp_561-40-50ms-1000g_1_conf561_merged_ROIs.tif

# %%
# Rename actin

# Function to extract the integer before the first underscore
def extract_integer(file_name):
    return int(file_name.split('_')[0])

# Iterate over both file lists
for img_file, actin_file in zip(img_merged_files, actin_files):
    # Extract the integers from the file names
    img_int = extract_integer(os.path.basename(img_file))
    actin_int = extract_integer(os.path.basename(actin_file))
    
    # Ensure the integers match
    if img_int == actin_int:
        # Extract the base name from the img_merged_file without the extension
        base_name = os.path.splitext(os.path.basename(img_file))[0]
        # Create the new name for the mask file
        new_name = f"{base_name}_actin.tif"
        # Construct the full path for the new name
        new_path = os.path.join(os.path.dirname(actin_file), new_name)
        
        # Rename the mask file
        shutil.move(actin_files, new_path)
        print(f"Renamed: {actin_file} -> {actin_file}")
    else:
        # Log a mismatch error
        print(f"Mismatch found: {img_file} and {actin_file}. Skipping rename.")
# Out:
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/2_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_2_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/2_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/3_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/3_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/4_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/4_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/5_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/5_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/6_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/6_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/7_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_actin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Actin/7_100tp_561-40-50ms-1000g_1_conf561_merged_actin.tif

# %%
# Rename tubulin

# Function to extract the integer before the first underscore
def extract_integer(file_name):
    return int(file_name.split('_')[0])

# Iterate over both file lists
for img_file, tubulin_file in zip(img_merged_files, tubulin_files):
    # Extract the integers from the file names
    img_int = extract_integer(os.path.basename(img_file))
    tubulin_int = extract_integer(os.path.basename(tubulin_file))
    
    # Ensure the integers match
    if img_int == tubulin_int:
        # Extract the base name from the img_merged_file without the extension
        base_name = os.path.splitext(os.path.basename(img_file))[0]
        # Create the new name for the mask file
        new_name = f"{base_name}_tubulin.tif"
        # Construct the full path for the new name
        new_path = os.path.join(os.path.dirname(tubulin_file), new_name)
        
        # Rename the mask file
        shutil.move(tubulin_file, new_path)
        print(f"Renamed: {tubulin_file} -> {new_path}")
    else:
        # Log a mismatch error
        print(f"Mismatch found: {img_file} and {tubulin_file}. Skipping rename.")
# Out:
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/2_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_2_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/2_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/3_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/3_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/4_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/4_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/5_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/5_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/6_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/6_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/7_17z-0-5_640-20-100ms_500g_561-30-50ms-1000g_488-10_50ms-50g_1_tubulin.tif -> /Volumes/gchao/bamfaile/Analysis/ACTB-KI/00_Batch20250228_iNs/D5/Unperturbed/Center_slice/Tubulin/7_100tp_561-40-50ms-1000g_1_conf561_merged_tubulin.tif

# %%
# Rename images

# Function to extract the integer before the first underscore
def extract_integer(file_name):
    return int(file_name.split('_')[0])

# Iterate over both file lists
for img_file, mask_file in zip(img_merged_files, mask_files):
    # Extract the integers from the file names
    img_int = extract_integer(os.path.basename(img_file))
    mask_int = extract_integer(os.path.basename(mask_file))
    
    # Ensure the integers match
    if mask_int == img_int:
        # Extract the base name from the img_merged_file without the extension
        base_name = os.path.splitext(os.path.basename(mask_file))[0]
        # Create the new name for the mask file
        new_name = f"{base_name}.tif"
        # Construct the full path for the new name
        new_path = os.path.join(os.path.dirname(img_file), new_name)
        
        # Rename the mask file
        shutil.move(img_file, new_path)
        print(f"Renamed: {img_file} -> {new_path}")
    else:
        # Log a mismatch error
        print(f"Mismatch found: {mask_file} and {img_file}. Skipping rename.")
# Out:
# Renamed: /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/1_100tp-500ms_561-40-50ms_1000g_1_conf561_merged.tif -> /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/1_100tp_561-40-50ms-1000g_1_conf561_merged.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/2_100tp-500ms_561-40-50ms_1000g_1_conf561_merged.tif -> /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/2_100tp_561-40-50ms-1000g_1_conf561_merged.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/3_100tp-500ms_561-40-50ms_1000g_1_conf561_merged.tif -> /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/3_100tp_561-40-50ms-1000g_1_conf561_merged.tif
# Renamed: /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/4_100tp-500ms_561-40-50ms_1000g_1_conf561_merged.tif -> /Volumes/gchao/bamfaile/Analysis/TUBB2B-KI/00_iNs_Batch20241011/D10/Unperturbed/500ms/Denoised_merged_renamed/4_100tp_561-40-50ms-1000g_1_conf561_merged.tif
