# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import load_trackmate_spots

# %%
spots_paths = [
    '/tungstenfs/scratch/gchao/bamfaile/Analysis/ACTB-KI/Batch20220930/D14/Slide1/Tables/100tp-561-100-50ms-1000g_488-10-50ms-1000g_pos14_1_w1conf561-488dual_ROI-1_denoised_spots.csv'
]

# %%
# ?load_trackmate_spots

# %%
clean_spots = []
for path in spots_paths:
    clean = load_trackmate_spots(path)
    clean_spots.append(clean)
# Out:
# hello

# %%
clean_spots[0]
# Out:
#         LABEL      ID TRACK_ID             QUALITY         POSITION_X  \
# 0    ID143154  143154        0   1937.309326171875  67.51197701999999
# 1    ID143215  143215        0   2213.644775390625        67.37749101
# 2    ID143363  143363        1  1889.0335693359375  68.72235110999999
# 3    ID143875  143875        1         4397.953125  68.72235110999999
# 4    ID143623  143623        1    2180.00439453125  68.72235110999999
# ..        ...     ...      ...                 ...                ...
# 492  ID144263  144263       42  1942.1177978515625          67.243005
# 493  ID144308  144308       42       5659.33203125  66.97403297999999
# 494  ID144293  144293       42     6673.2470703125  66.97403297999999
# 495  ID144361  144361       42    3516.51416015625  66.97403297999999
# 496  ID144335  144335       42        5627.0859375        67.10851899
#
#              POSITION_Y POSITION_Z           POSITION_T FRAME  \
# 0          111.89236032        0.0                 0.25     5
# ...
